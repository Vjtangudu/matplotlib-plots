# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x = np.random.randint(100,160,(30))
print(x)
# Out:
# [133 109 104 149 106 155 157 135 101 133 103 153 115 133 130 150 120 108
#  100 119 144 159 155 113 108 126 121 138 136 150]

# %%
number = [133, 109, 104, 149, 106, 155, 157, 135, 101, 133, 103, 153, 115, 133, 130, 150, 120, 108, 100, 119, 144, 159, 155,
          113, 108, 126, 121, 138, 136, 150,]
plt.hist(number,color='r',edgecolor='y')
plt.title('Histogram')
plt.ylabel('Data')
plt.xlabel('Numbers')
plt.show()

# %%
number = [133, 109, 104, 149, 106, 155, 157, 135, 101, 133, 103, 153, 115, 133, 130, 150, 120, 108, 100, 119, 144, 159, 155,
          113, 108, 126, 121, 138, 136, 150,]
lst = [100,110,120,130,140,150,160]
plt.hist(number,bins=lst,color='r',edgecolor='y')
plt.title('Histogram')
plt.ylabel('Data')
plt.xlabel('Numbers')
plt.show()

# %%
number = [133, 109, 104, 149, 106, 155, 157, 135, 101, 133, 103, 153, 115, 133, 130, 150, 120, 108, 100, 119, 144, 159, 155,
          113, 108, 126, 121, 138, 136, 150,]
lst = [100,110,120,130,140,150,160]
plt.hist(number,'auto',(70,200),color='r',edgecolor='y')
plt.title('Histogram')
plt.ylabel('Data')
plt.xlabel('Numbers')
plt.show()

# %%
number = [133, 109, 104, 149, 106, 155, 157, 135, 101, 133, 103, 153, 115, 133, 130, 150, 120, 108, 100, 119, 144, 159, 155,
          113, 108, 126, 121, 138, 136, 150,]
lst = [100,110,120,130,140,150,160]
plt.hist(number,'auto',color='r',edgecolor='y',rwidth=0.8)
plt.title('Histogram')
plt.ylabel('Data')
plt.xlabel('Numbers')
plt.show()

# %%
number = [133, 109, 104, 149, 106, 155, 157, 135, 101, 133, 103, 153, 115, 133, 130, 150, 120, 108, 100, 119, 144, 159, 155,
          113, 108, 126, 121, 138, 136, 150,]
lst = [100,110,120,130,140,150,160]
plt.hist(number,'auto',color='r',edgecolor='y',label='Python')#log=True)
plt.title('Histogram')
plt.ylabel('Data')
plt.xlabel('Numbers')
plt.axvline(135,color='b',label='line')
plt.legend()
plt.grid(axis='x',alpha=0.3)
plt.show()

# %%
number = [133, 109, 104, 149, 106, 155, 157, 135, 101, 133, 103, 153, 115, 133, 130, 150, 120, 108, 100, 119, 144, 159, 155,
          113, 108, 126, 121, 138, 136, 150,]
lst = [100,110,120,130,140,150,160]
plt.hist(number,bins=lst,color='r',align='mid',edgecolor='y')#,cumulative=-1)#bottom = 10 to start from 10 not from 0
plt.title('Histogram')
plt.ylabel('Data')
plt.xlabel('Numbers')
plt.show()

# %%
number = [133, 109, 104, 149, 106, 155, 157, 135, 101, 133, 103, 153, 115, 133, 130, 150, 120, 108, 100, 119, 144, 159, 155,
          113, 108, 126, 121, 138, 136, 150,]
lst = [100,110,120,130,140,150,160]
plt.hist(number,'auto',color='r',edgecolor='y',orientation='horizontal')#histtype='barstacked')
plt.title('Histogram')
plt.ylabel('Data')
plt.xlabel('Numbers')
plt.show()
