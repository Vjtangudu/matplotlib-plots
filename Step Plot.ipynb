# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [2,3,1,5,4]

plt.step(x,y,color='r',marker='o',mfc='Black',ms=10,label='python')
plt.grid()
plt.title('Step Plot')
plt.legend(loc=2)
plt.show()
